# %%
import cv2, os
base_path = r"/Documents/Dissertation/tobacco_data_zhugy/Tobacco800_SinglePage/SinglePageTIF/"
new_path = r"/Documents/Dissertation/tobacco_data_zhugy/Tobacco800_SinglePage/SinglePageTIF - Copy (2)/"
for infile in os.listdir(base_path):
    print ("file : " + infile)
    read = cv2.imread(base_path + infile)
    outfile = infile.split('.')[0] + '.jpg'
    cv2.imwrite(new_path+outfile,read,[int(cv2.IMWRITE_JPEG_QUALITY), 100])
# Out:
# file : aah97e00-page02_1.tif
# file : aah97e00-page02_2.tif
# file : aam09c00.tif
# file : aao54e00_1.tif
# file : aao54e00_2.tif
# file : abm69c00.tif
# file : acr64d00.tif
# file : adh36e00-page2_1.tif
# file : adh36e00-page2_2.tif
# file : adh36e00_1.tif
# file : adh36e00_2.tif
# file : adn64a00-page02_1.tif
# file : adn64a00-page02_2.tif
# file : adn64a00-page02_3.tif
# file : adp7aa00.tif
# file : adq65f00.tif
# file : aeb95e00.tif
# file : aee44c00.tif
# file : aeq93a00.tif
# file : aex05f00_1.tif
# file : aex05f00_2.tif
# file : afm90c00-first_1.tif
# file : afm90c00-first_2.tif
# file : agw39d00.tif
# file : ahs60f00.tif
# file : aik94f00-page02_1.tif
# file : aik94f00-page02_2.tif
# file : ail70a00.tif
# file : aji32e00-page02_1.tif
# file : aji32e00-page02_2.tif
# file : ajj10e00.tif
# file : ajy01c00.tif
# file : ajz31e00.tif
# file : aki32e00.tif
# file : ald41a00-ernest.tif
# file : alk3aa00.tif
# file : alz35d00.tif
# file : ama91d00-page03_1.tif
# ...
